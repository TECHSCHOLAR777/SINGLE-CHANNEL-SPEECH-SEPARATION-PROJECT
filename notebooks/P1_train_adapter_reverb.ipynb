# %% [markdown]
# # P1 — Train `adapter_reverb` (Stage 1)
#
# **USER RUNS TRAINING.** Requires cached RIR bank (`data/rirs/`) and wet references.
# Run after `adapter_noise`.

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))
DEVICE, EPOCHS, STEPS = 'cuda', 25, 200
cmd = f"{sys.executable} -m train.train_adapter --adapter reverb --config {ROOT/'configs/adapters/reverb.yaml'} --device {DEVICE} --epochs {EPOCHS} --steps-per-epoch {STEPS}"
print(cmd)
# !{cmd}
