# %% [markdown]
# # P3 — Joint polish + band recovery + calibration (Stage 4)
#
# **USER RUNS TRAINING.** Mandatory joint fine-tune of 3 adapters + gate at 0.1× Stage-1 LR.
# Then train band-recovery head; finally fit calibrators on held-out data only.

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))
print('1) Joint polish')
print(f"{sys.executable} -m train.train_joint_polish --device cuda --epochs 15")
print('2) Calibration')
print(f"{sys.executable} -m train.calibrate --out-dir {ROOT/'calibration/artifacts'}")
print('3) Band recovery: train BandRecoveryHead with SI-SNR on 16 kHz waveforms; validate dual-metric guard')
