# %% [markdown]
# # P1b — Universal adapter decision (Stage 2)
#
# **USER RUNS TRAINING before building the gate.**
#
# Decision rule (irreversible): if universal adapter is within 0.5 dB SI-SDRi of learned
# gating on the primary benchmark (reverb-noisy, N=2), adopt the simpler system and
# log the verdict in `docs/decisions.md`.

# %%
import sys
from pathlib import Path

ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))
print(f"{sys.executable} -m train.train_adapter --adapter universal --config {ROOT/'configs/adapters/universal.yaml'} --device cuda --epochs 30")
# After eval, append verdict to docs/decisions.md BEFORE starting P2 gate training.
