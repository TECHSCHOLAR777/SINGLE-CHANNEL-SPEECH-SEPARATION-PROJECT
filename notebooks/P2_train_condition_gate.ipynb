# %% [markdown]
# # P2 — Condition analyzer + gate (Stage 3)
#
# **USER RUNS TRAINING.** End with Principle-2 smoke test (`tests/principle2_test.py`).
# If clean Libri2Mix drops >0.1 dB vs base, raise `sparsity_weight` ×2 and retrain gate only.

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))
print(f"{sys.executable} -m train.train_gate --config {ROOT/'configs/gate.yaml'} --device cuda --epochs 15")
