# %% [markdown]
# # P1 — Train `adapter_codec` (Stage 1)
#
# **USER RUNS TRAINING.** Requires ffmpeg for Opus/AAC/AMR transforms.

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))
print(f"{sys.executable} -m train.train_adapter --adapter codec --config {ROOT/'configs/adapters/codec.yaml'} --device cuda --epochs 25")
